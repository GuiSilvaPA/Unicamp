# %%
nome = 'Gabriel Victor de Sousa Lopes'
print(f'Meu nome é {nome}')
# Out:
# Meu nome é Gabriel Victor de Sousa Lopes

# %% [markdown]
# #  Exercício: Modelo de Linguagem (Bengio 2003) - MLP + Embeddings

# %% [markdown]
# Neste exercício iremos treinar uma rede neural simples para prever a proxima palavra de um texto, data as palavras anteriores como entrada. Esta tarefa é chamada de "Modelagem da Língua".
#
# Este dataset já possui um tamanho razoável e é bem provável que você vai precisar rodar seus experimentos com GPU.
#
# Alguns conselhos úteis:
# - **ATENÇÃO:** o dataset é bem grande. Não dê comando de imprimí-lo.
# - Durante a depuração, faça seu dataset ficar bem pequeno, para que a depuração seja mais rápida e não precise de GPU. Somente ligue a GPU quando o seu laço de treinamento já está funcionando
# - Não deixe para fazer esse exercício na véspera. Ele é trabalhoso.

# %%
# iremos utilizar a biblioteca dos transformers para ter acesso ao tokenizador do BERT.
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.19.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)

# %% [markdown]
# ## Importação dos pacotes

# %%
import collections
import itertools
import functools
import math
import random

import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import DataLoader
from tqdm import tqdm_notebook

# %%
# Check which GPU we are using
# !nvidia-smi
# Out:
# Tue May 17 23:32:46 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    13W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
if torch.cuda.is_available(): 
   dev = "cuda:0"
else: 
   dev = "cpu"
device = torch.device(dev)
print('Using {}'.format(device))
# Out:
# Using cuda:0

# %% [markdown]
# ## Implementação do MyDataset

# %%
from typing import List


def tokenize(text: str, tokenizer):
    return tokenizer(text, return_tensors=None, add_special_tokens=False).input_ids


class MyDataset():
    def __init__(self, texts: List[str], tokenizer, context_size: int):
        # Escreva seu código aqui
        self.token_ids = []
        self.target =[]

        for text in texts:
          tokenized = tokenize(text,tokenizer)
          for i in range(len(tokenized)-context_size):
              self.token_ids.append(tokenized[i:i+context_size])   
              self.target.append(tokenized[i+context_size])

    def __len__(self):
        # Escreva seu código aqui
        return len(self.token_ids)

    def __getitem__(self, idx):
        # Escreva seu código aqui
        return torch.tensor(self.token_ids[idx]).long(), torch.tensor(self.target[idx]).long()

# %% [markdown]
# ## Teste se sua implementação do MyDataset está correta

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("neuralmind/bert-base-portuguese-cased")

dummy_texts = ['Eu gosto de correr', 'Ela gosta muito de comer pizza']

dummy_dataset = MyDataset(texts=dummy_texts, tokenizer=tokenizer, context_size=3)
dummy_loader = DataLoader(dummy_dataset, batch_size=6, shuffle=False)
print(dummy_dataset)
assert len(dummy_dataset) == 5
print('passou no assert de tamanho do dataset')

first_batch_input, first_batch_target = next(iter(dummy_loader))

correct_first_batch_input = torch.LongTensor(
    [[ 3396, 10303,   125],
     [ 1660,  5971,   785],
     [ 5971,   785,   125],
     [  785,   125,  1847],
     [  125,  1847, 13779]])

correct_first_batch_target = torch.LongTensor([13239,   125,  1847, 13779, 15616])

assert torch.equal(first_batch_input, correct_first_batch_input)
print('Passou no assert de input')
assert torch.equal(first_batch_target, correct_first_batch_target)
print('Passou no assert de target')
# Out:
# <__main__.MyDataset object at 0x7f5427a60f50>
# passou no assert de tamanho do dataset
# Passou no assert de input
# Passou no assert de target

# %% [markdown]
# # Carregamento do dataset

# %% [markdown]
# Iremos usar uma pequena amostra do dataset [BrWaC](https://www.inf.ufrgs.br/pln/wiki/index.php?title=BrWaC) para treinar e avaliar nosso modelo de linguagem.

# %%
# !wget -nc https://storage.googleapis.com/unicamp-dl/ia025a_2022s1/aula7/sample_brwac.txt
# Out:
# File ‘sample_brwac.txt’ already there; not retrieving.

# %%
# Load datasets
context_size = 9

valid_examples = 100
test_examples = 100
texts = open('sample_brwac.txt').readlines()

# print('Truncating for debugging purposes.')
# texts = texts[:500]  

training_texts = texts[:-(valid_examples + test_examples)]
valid_texts = texts[-(valid_examples + test_examples):-test_examples]
test_texts = texts[-test_examples:]

training_dataset = MyDataset(texts=training_texts, tokenizer=tokenizer, context_size=context_size)
valid_dataset = MyDataset(texts=valid_texts, tokenizer=tokenizer, context_size=context_size)
test_dataset = MyDataset(texts=test_texts, tokenizer=tokenizer, context_size=context_size)

# %%
print(f'training examples: {len(training_dataset)}')
print(f'valid examples: {len(valid_dataset)}')
print(f'test examples: {len(test_dataset)}')
# Out:
# training examples: 27675945
# valid examples: 82070
# test examples: 166726

# %%
from collections import OrderedDict

class LanguageModel(torch.nn.Module):

    def __init__(self, vocab_size, context_size, embedding_dim, hidden_size):
        """
        Implements the Neural Language Model proposed by Bengio et al."

        Args:
            vocab_size (int): Size of the input vocabulary.
            context_size (int): Size of the sequence to consider as context for prediction.
            embedding_dim (int): Dimension of the embedding layer for each word in the context.
            hidden_size (int): Size of the hidden layer.
        """
        # Escreva seu código aqui.
        super(LanguageModel, self).__init__()

        self.context_size = context_size
        self.embeddings_dim = embedding_dim
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)

        self.features = nn.Sequential(OrderedDict([                                    
            ('linear1', nn.Linear(self.context_size*self.embeddings_dim, hidden_size)), 
            ('Tanh1',nn.Tanh()), 
            ('linear2', nn.Linear(hidden_size, vocab_size, bias=False)),
            ]))
        
    def forward(self, inputs):
        """
        Args:
            inputs is a LongTensor of shape (batch_size, context_size)
        """
        # Escreva seu código aqui.

        out =  self.embeddings(inputs).view(-1,self.context_size*self.embeddings_dim)
        out = self.features(out)

        return out

# %% [markdown]
# ## Teste o modelo com um exemplo

# %%
model = LanguageModel(
    vocab_size=tokenizer.vocab_size,
    context_size=context_size,
    embedding_dim=64,
    hidden_size=128,
).to(device)

sample_train, _ = next(iter(DataLoader(training_dataset)))
sample_train_gpu = sample_train.to(device)
model(sample_train_gpu).shape
# Out:
# torch.Size([1, 29794])

# %%
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Number of model parameters: {num_params}')
# Out:
# Number of model parameters: 5794304

# %% [markdown]
# ## Assert da Perplexidade

# %%
random.seed(123)
np.random.seed(123)
torch.manual_seed(123)


def perplexity(logits, target):
    """
    Computes the perplexity.

    Args:
        logits: a FloatTensor of shape (batch_size, vocab_size)
        target: a LongTensor of shape (batch_size,)

    Returns:
        A float corresponding to the perplexity.
    """
    # Escreva seu código aqui.
    crossentropy =  nn.functional.cross_entropy(logits,target)
    p = torch.exp(crossentropy) 

    return p


n_examples = 1000

sample_train, target_token_ids = next(iter(DataLoader(training_dataset, batch_size=n_examples)))
sample_train_gpu = sample_train.to(device)
target_token_ids = target_token_ids.to(device)
logits = model(sample_train_gpu)

my_perplexity = perplexity(logits=logits, target=target_token_ids)

print(f'my perplexity:              {int(my_perplexity)}')
print(f'correct initial perplexity: {tokenizer.vocab_size}')

assert math.isclose(my_perplexity, tokenizer.vocab_size, abs_tol=2000)
print('Passou o no assert da perplexidade')
# Out:
# my perplexity:              30981
# correct initial perplexity: 29794
# Passou o no assert da perplexidade

# %% [markdown]
# ## Laço de Treinamento e Validação

# %%
max_examples = 200_000_000
eval_every_steps = 5000
lr = 3e-5


model = LanguageModel(
    vocab_size=tokenizer.vocab_size,
    context_size=context_size,
    embedding_dim=128,
    hidden_size=256,
).to(device)

train_loader = DataLoader(training_dataset, batch_size=1024, shuffle=True, drop_last=True)
validation_loader = DataLoader(valid_dataset, batch_size=1024)

optimizer = torch.optim.Adam(model.parameters(), lr=lr)


def train_step(input, target):
    model.train()
    model.zero_grad()

    logits = model(input.to(device))
    loss = nn.functional.cross_entropy(logits, target.to(device))
    loss.backward()
    optimizer.step()

    return loss.item()


def validation_step(input, target):
    logits = model(input)
    loss = nn.functional.cross_entropy(logits, target)
    return loss.item()


train_losses = []
n_examples = 0
step = 0
while n_examples < max_examples:
    for input, target in train_loader:
        loss = train_step(input.to(device), target.to(device)) 
        train_losses.append(loss)
        
        if step % eval_every_steps == 0:
            train_ppl = np.exp(np.average(train_losses))

            with torch.no_grad():
                valid_ppl = np.exp(np.average([
                    validation_step(input.to(device), target.to(device))
                    for input, target in validation_loader]))

            print(f'{step} steps; {n_examples} examples so far; train ppl: {train_ppl:.2f}, valid ppl: {valid_ppl:.2f}')
            train_losses = []

        n_examples += len(input)  # Increment of batch size
        step += 1
        if n_examples >= max_examples:
            break
# Out:
# 0 steps; 0 examples so far; train ppl: 30907.90, valid ppl: 30742.89
# 5000 steps; 5120000 examples so far; train ppl: 2419.41, valid ppl: 1432.51
# 10000 steps; 10240000 examples so far; train ppl: 1252.33, valid ppl: 1091.45
# 15000 steps; 15360000 examples so far; train ppl: 993.65, valid ppl: 904.11
# 20000 steps; 20480000 examples so far; train ppl: 846.81, valid ppl: 793.20
# 25000 steps; 25600000 examples so far; train ppl: 753.74, valid ppl: 715.88
# 30000 steps; 30720000 examples so far; train ppl: 683.57, valid ppl: 656.53
# 35000 steps; 35840000 examples so far; train ppl: 630.68, valid ppl: 607.08
# 40000 steps; 40960000 examples so far; train ppl: 587.78, valid ppl: 566.61
# 45000 steps; 46080000 examples so far; train ppl: 550.77, valid ppl: 530.69
# 50000 steps; 51200000 examples so far; train ppl: 517.43, valid ppl: 500.13
# 55000 steps; 56320000 examples so far; train ppl: 488.12, valid ppl: 473.80
# 60000 steps; 61440000 examples so far; train ppl: 461.43, valid ppl: 450.41
# 65000 steps; 66560000 examples so far; train ppl: 439.85, valid ppl: 429.27
# 70000 steps; 71680000 examples so far; train ppl: 421.04, valid ppl: 410.93
# 75000 steps; 76800000 examples so far; train ppl: 404.07, valid ppl: 394.92
# 80000 steps; 81920000 examples so far; train ppl: 388.96, valid ppl: 380.58
# 85000 steps; 87040000 examples so far; train ppl: 371.62, valid ppl: 367.68
# 90000 steps; 92160000 examples so far; train ppl: 360.59, valid ppl: 355.75
# 95000 steps; 97280000 examples so far; train ppl: 349.77, valid ppl: 345.36
# 100000 steps; 102400000 examples so far; train ppl: 340.06, valid ppl: 335.80
# 105000 steps; 107520000 examples so far; train ppl: 331.93, valid ppl: 327.14
# 110000 steps; 112640000 examples so far; train ppl: 321.78, valid ppl: 319.38
# 115000 steps; 117760000 examples so far; train ppl: 313.08, valid ppl: 312.15
# 120000 steps; 122880000 examples so far; train ppl: 306.42, valid ppl: 305.40
# 125000 steps; 128000000 examples so far; train ppl: 299.97, valid ppl: 298.86
# 130000 steps; 133120000 examples so far; train ppl: 294.42, valid ppl: 293.14
# 135000 steps; 138240000 examples so far; train ppl: 288.54, valid ppl: 287.55
# 140000 steps; 143360000 examples so far; train ppl: 281.38, valid ppl: 282.81
# 145000 steps; 148480000 examples so far; train ppl: 277.25, valid ppl: 278.02
# 150000 steps; 153600000 examples so far; train ppl: 273.13, valid ppl: 273.93
# 155000 steps; 158720000 examples so far; train ppl: 268.76, valid ppl: 269.73
# 160000 steps; 163840000 examples so far; train ppl: 264.81, valid ppl: 265.88
# 165000 steps; 168960000 examples so far; train ppl: 259.82, valid ppl: 262.25
# 170000 steps; 174080000 examples so far; train ppl: 255.75, valid ppl: 258.77
# 175000 steps; 179200000 examples so far; train ppl: 253.12, valid ppl: 255.46
# 180000 steps; 184320000 examples so far; train ppl: 250.06, valid ppl: 252.42
# 185000 steps; 189440000 examples so far; train ppl: 247.40, valid ppl: 249.51
# 190000 steps; 194560000 examples so far; train ppl: 243.87, valid ppl: 246.67
# 195000 steps; 199680000 examples so far; train ppl: 239.74, valid ppl: 244.19

# %% [markdown]
# ## Avaliação final no dataset de teste
#
#
# Bonus: o modelo com menor perplexidade no dataset de testes ganhará 0.5 ponto na nota final.

# %%
test_loader = DataLoader(test_dataset, batch_size=64)

with torch.no_grad():
    test_ppl = np.exp(np.average([
        validation_step(input.to(device), target.to(device))
        for input, target in test_loader
    ]))

print(f'test perplexity: {test_ppl}')
# Out:
# test perplexity: 231.36585038130298

# %% [markdown]
# ## Teste seu modelo com uma sentença
#
# Escolha uma sentença gerada pelo modelo que ache interessante.

# %%
prompt = 'Eu gosto de comer pizza pois me faz'
max_output_tokens = 10

for _ in range(max_output_tokens):
    input_ids = tokenize(text=prompt, tokenizer=tokenizer)
    input_ids_truncated = input_ids[-context_size:]  # Usamos apenas os últimos <context_size> tokens como entrada para o modelo.
    logits = model(torch.LongTensor([input_ids_truncated]).to(device))
    # Ao usarmos o argmax, a saída do modelo em cada passo é token de maior probabilidade.
    # Isso se chama decodificação gulosa (greedy decoding).
    predicted_id = torch.argmax(logits).item()
    input_ids += [predicted_id]  # Concatenamos a entrada com o token escolhido nesse passo.
    prompt = tokenizer.decode(input_ids)
    print(prompt)
# Out:
# Eu gosto de comer pizza pois me faz parte
# Eu gosto de comer pizza pois me faz parte do
# Eu gosto de comer pizza pois me faz parte do que
# Eu gosto de comer pizza pois me faz parte do que o
# Eu gosto de comer pizza pois me faz parte do que o que
# Eu gosto de comer pizza pois me faz parte do que o que é
# Eu gosto de comer pizza pois me faz parte do que o que é o
# Eu gosto de comer pizza pois me faz parte do que o que é o que
# Eu gosto de comer pizza pois me faz parte do que o que é o que é
# Eu gosto de comer pizza pois me faz parte do que o que é o que é o

# %%
prompt = 'A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora'
max_output_tokens = 10

for _ in range(max_output_tokens):
    input_ids = tokenize(text=prompt, tokenizer=tokenizer)
    input_ids_truncated = input_ids[-context_size:]  # Usamos apenas os últimos <context_size> tokens como entrada para o modelo.
    logits = model(torch.LongTensor([input_ids_truncated]).to(device))
    # Ao usarmos o argmax, a saída do modelo em cada passo é token de maior probabilidade.
    # Isso se chama decodificação gulosa (greedy decoding).
    predicted_id = torch.argmax(logits).item()
    input_ids += [predicted_id]  # Concatenamos a entrada com o token escolhido nesse passo.
    prompt = tokenizer.decode(input_ids)
    print(prompt)
# Out:
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos maiores
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos maiores,
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos maiores, que
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos maiores, que não
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos maiores, que não é
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos maiores, que não é o
# A Justiça do Trabalho de Mato Grosso do Sul condenou uma operadora de um dos maiores, que não é o que

# %%
prompt = 'Sem representante brasileiro, foi realizada nesta quarta-feira'
max_output_tokens = 10

for _ in range(max_output_tokens):
    input_ids = tokenize(text=prompt, tokenizer=tokenizer)
    input_ids_truncated = input_ids[-context_size:]  # Usamos apenas os últimos <context_size> tokens como entrada para o modelo.
    logits = model(torch.LongTensor([input_ids_truncated]).to(device))
    # Ao usarmos o argmax, a saída do modelo em cada passo é token de maior probabilidade.
    # Isso se chama decodificação gulosa (greedy decoding).
    predicted_id = torch.argmax(logits).item()
    input_ids += [predicted_id]  # Concatenamos a entrada com o token escolhido nesse passo.
    prompt = tokenizer.decode(input_ids)
    print(prompt)
# Out:
# Sem representante brasileiro, foi realizada nesta quarta - feira,
# Sem representante brasileiro, foi realizada nesta quarta - feira, o
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que é
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que é o
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que é o que
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que é o que se
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que é o que se refere
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que é o que se refere a
# Sem representante brasileiro, foi realizada nesta quarta - feira, o que é o que se refere a uma
